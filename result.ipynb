# %%
from src.eval_job import *
run_jobs()
# Out:
# {'gamma_param': [25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300], 'action_fair_type': [None], 'loss_fair_type': [None]}
# {'gamma_param': 25, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 50, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 75, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 100, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 125, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 150, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 175, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 200, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 225, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 250, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 275, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 300, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': [0.001, 0.01, 0.1, 1], 'cb_type': ['dr', 'ips', 'mtr'], 'bag': [2, 4, 8, 16]}
# {'learning_rate': 0.001, 'cb_type': 'dr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'bag': 2}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--bag', '2']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'bag': 4}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--bag', '4']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'bag': 8}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--bag', '8']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'bag': 16}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--bag', '16']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': [0.001, 0.01, 0.1, 1], 'cb_type': ['dr', 'ips', 'mtr'], 'regcbopt': [None], 'mellowness': [0.1, 0.01, 0.001]}
# {'learning_rate': 0.001, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.01}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.01']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'regcbopt': None, 'mellowness': 0.001}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--regcbopt', '--mellowness', '0.001']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': [0.001, 0.01, 0.1, 1], 'cb_type': ['dr', 'ips', 'mtr'], 'epsilon': [0, 0.02, 0.05, 0.1]}
# {'learning_rate': 0.001, 'cb_type': 'dr', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'epsilon': 0.05}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--epsilon', '0.05']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'dr', 'epsilon': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'dr', '--epsilon', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'epsilon': 0.05}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--epsilon', '0.05']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'ips', 'epsilon': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'ips', '--epsilon', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'epsilon': 0.05}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--epsilon', '0.05']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.001, 'cb_type': 'mtr', 'epsilon': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.001', '--cb_type', 'mtr', '--epsilon', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'epsilon': 0.05}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--epsilon', '0.05']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'dr', 'epsilon': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'dr', '--epsilon', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'epsilon': 0.05}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--epsilon', '0.05']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'ips', 'epsilon': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'ips', '--epsilon', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'epsilon': 0.05}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--epsilon', '0.05']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.01, 'cb_type': 'mtr', 'epsilon': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.01', '--cb_type', 'mtr', '--epsilon', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'epsilon': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--epsilon', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'dr', 'epsilon': 0.02}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'dr', '--epsilon', '0.02']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# ...
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'cover': 8, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--cover', '8', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'ips', 'cover': 8, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'ips', '--cover', '8', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 1, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '1', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 1, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '1', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 1, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '1', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 4, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '4', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 4, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '4', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 4, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '4', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 8, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '8', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 8, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '8', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 0.1, 'cb_type': 'mtr', 'cover': 8, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '0.1', '--cb_type', 'mtr', '--cover', '8', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 1, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '1', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 1, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '1', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 1, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '1', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 4, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '4', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 4, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '4', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 4, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '4', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 8, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '8', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 8, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '8', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'dr', 'cover': 8, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'dr', '--cover', '8', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 1, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '1', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 1, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '1', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 1, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '1', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 4, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '4', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 4, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '4', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 4, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '4', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 8, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '8', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 8, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '8', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'ips', 'cover': 8, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'ips', '--cover', '8', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 1, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '1', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 1, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '1', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 1, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '1', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 4, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '4', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 4, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '4', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 4, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '4', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 8, 'psi': 0}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '8', '--psi', '0']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 8, 'psi': 0.1}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '8', '--psi', '0.1']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'learning_rate': 1, 'cb_type': 'mtr', 'cover': 8, 'psi': 0.5}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--cbify', '2', '--learning_rate', '1', '--cb_type', 'mtr', '--cover', '8', '--psi', '0.5']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'class': ['linear']}
# {'class': 'linear'}
# ['vw', 'src/datasets/adult/adult_2.vw.gz', '-b', '24', '--progress', '1', '--oaa', '2']
# 32561
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000

# %%
from src.falcon_eval_fair import *
run_falcon_fair(action_type = 'group-action-parity', dataset = 'compas')
run_falcon_fair(action_type = 'individual-parity', dataset = 'compas')
# Out:
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000

# %%
from src.falcon_eval_fair import *
run_falcon_fair_loss('adult')

# %%
# (TODO): test minmax regressor
from src.falcon_eval_fair import *
run_falcon_fair_loss('adult')
# Out:
# 3
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-01-24
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000

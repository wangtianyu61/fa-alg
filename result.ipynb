# %%
from src.eval_job import *
run_jobs()
# Out:
# {'gamma_param': [25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300], 'action_fair_type': [None], 'loss_fair_type': [None]}
# {'gamma_param': 25, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 50, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# {'gamma_param': 75, 'action_fair_type': None, 'loss_fair_type': None}
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# ...

# %%
from src.falcon_eval_fair import *
run_falcon_fair(action_type = 'group-action-parity', dataset = 'compas')
run_falcon_fair(action_type = 'individual-parity', dataset = 'compas')
# Out:
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000

# %%
from src.falcon_eval_fair import *
run_falcon_fair_loss('adult')

# %%
from src.falcon_eval_fair import *
run_falcon_fair_loss('adult')
# Out:
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 3
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# ...
